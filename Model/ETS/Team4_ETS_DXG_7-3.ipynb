# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/stock-data/DIG Historical Data 1_6.csv
# /kaggle/input/stock-data/NVL Historical Data 1_6.csv
# /kaggle/input/stock-data/DXG Historical Data 1_6.csv

# %%
# 1. Các thư viện cần thiết
import numpy as np
import pandas as pd
from scipy.stats import boxcox
from pandas.plotting import lag_plot
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from pandas import DataFrame
from pandas import Grouper
from math import sqrt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.holtwinters import SimpleExpSmoothing # SES
from statsmodels.tsa.holtwinters import Holt # Holts Exponential Smoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.exponential_smoothing.ets import ETSModel
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import seaborn as sns
from collections import Counter
sns.set_style('darkgrid')
# from dataprep.eda import plot, plot_correlation, plot_missing, create_report
import plotly.express as px
from plotly.offline import plot as off
import plotly.figure_factory as ff
import plotly.io as pio
from sklearn.preprocessing import StandardScaler, LabelEncoder, MinMaxScaler, scale
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error
from sklearn.model_selection import GridSearchCV, KFold, StratifiedKFold, cross_val_score, \
                                    train_test_split, RandomizedSearchCV
from itertools import product
from tqdm import tqdm_notebook
import warnings
warnings.filterwarnings('ignore')

# %%
# 2. Đọc file csv và gắng index với giá Price
df = pd.read_csv('/kaggle/input/stock-data/DXG Historical Data 1_6.csv')
df['Price'] = df['Price'].str.replace('$', '', regex=True)
df['Price'] = df['Price'].str.replace(',', '', regex=True)
df['Price'] = df.Price.astype(float)
df = df[::-1]
df1 = df[['Price']]
df = df.dropna() # Drop missing values
df1 = df1.reset_index(drop=True) # Reset the inde
df1
# Out:
#         Price
# 0     13401.4
# 1     13371.1
# 2     13522.4
# 3     13159.4
# 4     14066.9
# ...       ...
# 1593  16550.0
# 1594  16800.0
# 1595  16850.0
# 1596  16850.0
# 1597  16800.0
#
# [1598 rows x 1 columns]

# %%
train_size = int(0.7 * len(df1))

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
def optimize_ETS(train_df, param_list):
    results = []
    endog = df1['Price'].to_numpy()
    
    for order in tqdm_notebook(param_list):
        if order[4] == True and order[1] == None:
            continue
        else:
            model = ETSModel(endog,
                             error = order[0],
                             trend = order[1],
                             seasonal = order[2],
                             damped_trend = order[4],
                             seasonal_periods = order[3]).fit()
              
            aic = model.aic
            mae = model.mae
            results.append([order, aic, mae])

    result_df = pd.DataFrame(results)
    result_df.columns = ["(e, t, s)", "AIC", "MAE"]
    #Sort in ascending order, lower MSE is better
    result_df = result_df.sort_values(by='MAE', ascending=True).reset_index(drop=True)
    
    return result_df

# %%
e = ['add', 'mul']
t = ['add', 'mul', None]
s = ['add', 'mul', None]
p = [7, 30, 90]
d = [True, False]

param_list = list(product(e,t,s,p,d))

# %%
#Chạy trên tập DXG với tỉ lệ 8-2 làm tham số để so sánh
result_data = optimize_ETS(train_data, param_list)
result_data
# Out:
#   0%|          | 0/108 [00:00<?, ?it/s]
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           12     M =           10
#
# At X0         1 variables are exactly at the bounds
#
# At iterate    0    f=  9.47526D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.50376D+00    |proj g|=  9.99800D-01
#
# At iterate    2    f=  8.49950D+00    |proj g|=  2.52233D-01
#
# At iterate    3    f=  8.49561D+00    |proj g|=  2.18597D-01
#
# At iterate    4    f=  8.48379D+00    |proj g|=  1.81627D-01
#
# At iterate    5    f=  8.48280D+00    |proj g|=  5.56412D-02
#
# At iterate    6    f=  8.48234D+00    |proj g|=  3.94149D-02
#
# At iterate    7    f=  8.48177D+00    |proj g|=  2.24533D-02
#
# At iterate    8    f=  8.48156D+00    |proj g|=  1.81014D-02
#
# At iterate    9    f=  8.48153D+00    |proj g|=  1.80661D-02
#
# At iterate   10    f=  8.48137D+00    |proj g|=  4.98783D-03
#
# At iterate   11    f=  8.48134D+00    |proj g|=  4.23217D-03
#
# At iterate   12    f=  8.48128D+00    |proj g|=  8.36877D-03
#
# At iterate   13    f=  8.48118D+00    |proj g|=  1.64320D-02
#
# At iterate   14    f=  8.48097D+00    |proj g|=  2.06915D-02
#
# At iterate   15    f=  8.48066D+00    |proj g|=  1.48983D-02
#
# At iterate   16    f=  8.48043D+00    |proj g|=  7.69660D-03
#
# At iterate   17    f=  8.48042D+00    |proj g|=  2.37288D-02
#
# At iterate   18    f=  8.48042D+00    |proj g|=  3.39750D-02
#
# At iterate   19    f=  8.48038D+00    |proj g|=  7.32623D-03
#
# At iterate   20    f=  8.48038D+00    |proj g|=  5.10525D-04
#
# At iterate   21    f=  8.48038D+00    |proj g|=  1.35181D-04
#
# At iterate   22    f=  8.48038D+00    |proj g|=  9.94760D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    12     22     25     25     0     2   9.948D-06   8.480D+00
#   F =   8.4803759142154860
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           11     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.54813D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.49335D+00    |proj g|=  1.23884D-01
#
# At iterate    2    f=  8.49284D+00    |proj g|=  2.42167D-02
#
# At iterate    3    f=  8.49244D+00    |proj g|=  1.50310D-02
#   ys=-9.590E-05  -gs= 3.422E-04 BFGS update SKIPPED
#
# At iterate    4    f=  8.49243D+00    |proj g|=  5.87779D-03
#
# At iterate    5    f=  8.49242D+00    |proj g|=  6.02416D-03
#
# At iterate    6    f=  8.49241D+00    |proj g|=  1.01783D-02
#
# At iterate    7    f=  8.49237D+00    |proj g|=  2.84011D-02
#
# At iterate    8    f=  8.49228D+00    |proj g|=  5.06908D-02
#
# At iterate    9    f=  8.49205D+00    |proj g|=  8.54129D-02
#
# At iterate   10    f=  8.49155D+00    |proj g|=  1.05086D-01
#
# At iterate   11    f=  8.49072D+00    |proj g|=  5.66793D-02
#
# At iterate   12    f=  8.49067D+00    |proj g|=  1.25418D-02
#
# At iterate   13    f=  8.49066D+00    |proj g|=  1.30971D-03
#
# At iterate   14    f=  8.49066D+00    |proj g|=  3.07310D-05
#
# At iterate   15    f=  8.49066D+00    |proj g|=  7.46070D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    11     15     17     19     1     2   7.461D-06   8.491D+00
#   F =   8.4906630037888533
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           35     M =           10
#
# At X0         1 variables are exactly at the bounds
#
# At iterate    0    f=  9.48318D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.50081D+00    |proj g|=  1.83483D-01
#
# At iterate    2    f=  8.49650D+00    |proj g|=  1.09339D-01
#
# At iterate    3    f=  8.49350D+00    |proj g|=  2.83574D-02
#
# At iterate    4    f=  8.49324D+00    |proj g|=  5.90976D-03
#
# At iterate    5    f=  8.49322D+00    |proj g|=  4.36481D-03
#
# At iterate    6    f=  8.49320D+00    |proj g|=  2.00888D-03
#
# At iterate    7    f=  8.49319D+00    |proj g|=  1.55893D-03
#
# At iterate    8    f=  8.49319D+00    |proj g|=  1.87406D-04
#
# At iterate    9    f=  8.49319D+00    |proj g|=  1.04272D-04
#
# At iterate   10    f=  8.49319D+00    |proj g|=  1.04095D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    35     10     11     15     0     2   1.041D-04   8.493D+00
#   F =   8.4931938610250697
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           34     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.55703D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.50103D+00    |proj g|=  9.45022D-05
#
# At iterate    2    f=  8.50091D+00    |proj g|=  8.28125D-01
#
# At iterate    3    f=  8.49940D+00    |proj g|=  5.88483D-01
#
# At iterate    4    f=  8.49745D+00    |proj g|=  1.82873D-01
#
# At iterate    5    f=  8.49717D+00    |proj g|=  5.89280D-02
#
# At iterate    6    f=  8.49713D+00    |proj g|=  9.20366D-03
#
# At iterate    7    f=  8.49713D+00    |proj g|=  5.68257D-04
#
# At iterate    8    f=  8.49713D+00    |proj g|=  1.54543D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    34      8     22     11     0     2   1.545D-05   8.497D+00
#   F =   8.4971332193121611
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           95     M =           10
#
# At X0         1 variables are exactly at the bounds
#
# At iterate    0    f=  9.49727D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.49108D+00    |proj g|=  2.01758D-01
#
# At iterate    2    f=  8.48600D+00    |proj g|=  1.18958D-01
#
# At iterate    3    f=  8.48254D+00    |proj g|=  3.17131D-02
#
# At iterate    4    f=  8.48222D+00    |proj g|=  6.49525D-03
#
# At iterate    5    f=  8.48220D+00    |proj g|=  5.36193D-03
#
# At iterate    6    f=  8.48219D+00    |proj g|=  4.20904D-03
#
# At iterate    7    f=  8.48218D+00    |proj g|=  3.96092D-03
#
# At iterate    8    f=  8.48217D+00    |proj g|=  1.85878D-03
#
# At iterate    9    f=  8.48216D+00    |proj g|=  3.24718D-04
#
# At iterate   10    f=  8.48216D+00    |proj g|=  8.52651D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    95     10     12     15     0     2   8.527D-06   8.482D+00
#   F =   8.4821644386696882
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           94     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.57228D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.49138D+00    |proj g|=  1.79412D-05
#
# At iterate    2    f=  8.49116D+00    |proj g|=  1.61648D-05
#
# At iterate    3    f=  8.49038D+00    |proj g|=  8.70415D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    94      3     26      6     0     3   8.704D-06   8.490D+00
#   F =   8.4903830661280573
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           12     M =           10
#
# At X0         1 variables are exactly at the bounds
#
# At iterate    0    f=  9.47526D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.48677D+00    |proj g|=  4.18568D-01
#
# At iterate    2    f=  8.48099D+00    |proj g|=  2.03220D-01
#
# At iterate    3    f=  8.48000D+00    |proj g|=  2.03406D-01
#
# At iterate    4    f=  8.47827D+00    |proj g|=  2.06543D-01
#
# At iterate    5    f=  8.47645D+00    |proj g|=  1.63028D-01
#
# At iterate    6    f=  8.47255D+00    |proj g|=  4.12768D-01
#
# At iterate    7    f=  8.47114D+00    |proj g|=  1.00072D-01
#
# At iterate    8    f=  8.47056D+00    |proj g|=  9.13962D-02
#
# At iterate    9    f=  8.46974D+00    |proj g|=  1.43654D-01
#
# At iterate   10    f=  8.46931D+00    |proj g|=  4.96286D-02
#
# At iterate   11    f=  8.46907D+00    |proj g|=  5.86700D-02
#
# At iterate   12    f=  8.46885D+00    |proj g|=  1.48079D-01
#
# At iterate   13    f=  8.46858D+00    |proj g|=  6.62647D-02
#
# At iterate   14    f=  8.46843D+00    |proj g|=  1.49003D-02
#
# At iterate   15    f=  8.46838D+00    |proj g|=  2.26581D-02
#
# At iterate   16    f=  8.46837D+00    |proj g|=  5.52074D-03
#
# At iterate   17    f=  8.46836D+00    |proj g|=  1.01355D-02
#
# At iterate   18    f=  8.46835D+00    |proj g|=  1.59607D-02
#
# At iterate   19    f=  8.46835D+00    |proj g|=  8.39577D-03
#
# At iterate   20    f=  8.46834D+00    |proj g|=  1.38073D-02
#
# At iterate   21    f=  8.46833D+00    |proj g|=  2.25308D-02
#
# At iterate   22    f=  8.46833D+00    |proj g|=  2.25789D-02
#
# At iterate   23    f=  8.46833D+00    |proj g|=  2.22489D-02
#
# At iterate   24    f=  8.46832D+00    |proj g|=  8.43308D-03
#
# At iterate   25    f=  8.46832D+00    |proj g|=  4.97202D-03
#
# At iterate   26    f=  8.46832D+00    |proj g|=  1.59659D-03
#
# At iterate   27    f=  8.46832D+00    |proj g|=  5.09282D-04
#
# At iterate   28    f=  8.46832D+00    |proj g|=  2.19913D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    12     28     34     32     0     1   2.199D-04   8.468D+00
#   F =   8.4683224439365219
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           11     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.54811D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.49315D+00    |proj g|=  1.73045D-01
#
# At iterate    2    f=  8.48696D+00    |proj g|=  1.37931D-01
#
# At iterate    3    f=  8.48599D+00    |proj g|=  1.13733D-01
#
# At iterate    4    f=  8.48370D+00    |proj g|=  3.49766D-01
#
# At iterate    5    f=  8.48232D+00    |proj g|=  5.07831D-01
#
# At iterate    6    f=  8.48203D+00    |proj g|=  1.65072D-01
#
# At iterate    7    f=  8.48091D+00    |proj g|=  2.06212D-01
#
# At iterate    8    f=  8.48033D+00    |proj g|=  1.43961D-01
#
# At iterate    9    f=  8.48004D+00    |proj g|=  2.47019D-01
#
# At iterate   10    f=  8.47955D+00    |proj g|=  8.53829D-02
#
# At iterate   11    f=  8.47912D+00    |proj g|=  1.30403D-01
#
# At iterate   12    f=  8.47866D+00    |proj g|=  4.63576D-02
#
# At iterate   13    f=  8.47856D+00    |proj g|=  4.46867D-02
#
# At iterate   14    f=  8.47848D+00    |proj g|=  3.38861D-02
#
# At iterate   15    f=  8.47843D+00    |proj g|=  4.31672D-02
#
# At iterate   16    f=  8.47841D+00    |proj g|=  1.81757D-02
#
# At iterate   17    f=  8.47841D+00    |proj g|=  1.03928D-02
#
# At iterate   18    f=  8.47841D+00    |proj g|=  6.37783D-03
#
# At iterate   19    f=  8.47841D+00    |proj g|=  6.57501D-03
#
# At iterate   20    f=  8.47841D+00    |proj g|=  1.15978D-03
#
# At iterate   21    f=  8.47841D+00    |proj g|=  4.48708D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    11     21     29     29     0     1   4.487D-04   8.478D+00
#   F =   8.4784108220488914
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           35     M =           10
#
# At X0         1 variables are exactly at the bounds
#
# At iterate    0    f=  9.46718D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.52958D+00    |proj g|=  9.56563D-01
#
# At iterate    2    f=  8.46106D+00    |proj g|=  3.50245D-01
#
# At iterate    3    f=  8.44637D+00    |proj g|=  2.84042D-01
#
# At iterate    4    f=  8.42726D+00    |proj g|=  1.96709D-01
#
# At iterate    5    f=  8.42645D+00    |proj g|=  4.77028D-01
#
# At iterate    6    f=  8.41997D+00    |proj g|=  1.57203D-01
#
# At iterate    7    f=  8.41830D+00    |proj g|=  1.45753D-01
#
# At iterate    8    f=  8.41557D+00    |proj g|=  1.42910D-01
#
# At iterate    9    f=  8.41204D+00    |proj g|=  1.63906D-01
#
# At iterate   10    f=  8.41010D+00    |proj g|=  2.24606D-01
#
# At iterate   11    f=  8.40730D+00    |proj g|=  6.06668D-02
#
# At iterate   12    f=  8.40697D+00    |proj g|=  2.82483D-02
#
# At iterate   13    f=  8.40681D+00    |proj g|=  2.75946D-02
#
# At iterate   14    f=  8.40658D+00    |proj g|=  4.85368D-02
#
# At iterate   15    f=  8.40625D+00    |proj g|=  5.03222D-02
#
# At iterate   16    f=  8.40586D+00    |proj g|=  3.31879D-02
#
# At iterate   17    f=  8.40563D+00    |proj g|=  2.94897D-02
#
# At iterate   18    f=  8.40553D+00    |proj g|=  2.29456D-02
#
# At iterate   19    f=  8.40548D+00    |proj g|=  1.95042D-02
#
# At iterate   20    f=  8.40531D+00    |proj g|=  3.40286D-02
#
# At iterate   21    f=  8.40516D+00    |proj g|=  4.12999D-02
#
# At iterate   22    f=  8.40502D+00    |proj g|=  5.59581D-02
#
# At iterate   23    f=  8.40483D+00    |proj g|=  2.66400D-02
#
# At iterate   24    f=  8.40470D+00    |proj g|=  2.01325D-02
#
# At iterate   25    f=  8.40461D+00    |proj g|=  2.86571D-02
#
# At iterate   26    f=  8.40458D+00    |proj g|=  3.42188D-02
#
# At iterate   27    f=  8.40453D+00    |proj g|=  9.34239D-03
#
# At iterate   28    f=  8.40451D+00    |proj g|=  1.06077D-02
#
# At iterate   29    f=  8.40449D+00    |proj g|=  1.26583D-02
#
# At iterate   30    f=  8.40445D+00    |proj g|=  1.41158D-02
#
# At iterate   31    f=  8.40441D+00    |proj g|=  3.25002D-02
#
# At iterate   32    f=  8.40432D+00    |proj g|=  2.16071D-02
#
# At iterate   33    f=  8.40422D+00    |proj g|=  1.93829D-02
#
# At iterate   34    f=  8.40415D+00    |proj g|=  2.42784D-02
#
# At iterate   35    f=  8.40414D+00    |proj g|=  5.43464D-02
#
# At iterate   36    f=  8.40404D+00    |proj g|=  1.74222D-02
#
# At iterate   37    f=  8.40402D+00    |proj g|=  8.66951D-03
#
# At iterate   38    f=  8.40400D+00    |proj g|=  1.05707D-02
#
# At iterate   39    f=  8.40398D+00    |proj g|=  7.43157D-03
#
# At iterate   40    f=  8.40397D+00    |proj g|=  9.41043D-03
#
# At iterate   41    f=  8.40396D+00    |proj g|=  6.49560D-03
#
# At iterate   42    f=  8.40395D+00    |proj g|=  1.10697D-02
#
# At iterate   43    f=  8.40394D+00    |proj g|=  1.04947D-02
#
# At iterate   44    f=  8.40393D+00    |proj g|=  1.52529D-02
#
# At iterate   45    f=  8.40393D+00    |proj g|=  3.42695D-03
#
# At iterate   46    f=  8.40393D+00    |proj g|=  2.35438D-03
#
# At iterate   47    f=  8.40393D+00    |proj g|=  2.19558D-03
#
# At iterate   48    f=  8.40393D+00    |proj g|=  1.99822D-03
#
# At iterate   49    f=  8.40392D+00    |proj g|=  2.02434D-03
#
# At iterate   50    f=  8.40392D+00    |proj g|=  1.39977D-03
#
# At iterate   51    f=  8.40392D+00    |proj g|=  1.68807D-03
#
# At iterate   52    f=  8.40392D+00    |proj g|=  1.35998D-03
#
# At iterate   53    f=  8.40392D+00    |proj g|=  9.71490D-04
#
# At iterate   54    f=  8.40392D+00    |proj g|=  5.55822D-04
#
# At iterate   55    f=  8.40392D+00    |proj g|=  3.59179D-04
#
# At iterate   56    f=  8.40392D+00    |proj g|=  3.50475D-04
#
# At iterate   57    f=  8.40392D+00    |proj g|=  6.27587D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    35     57     63     61     0     3   6.276D-04   8.404D+00
#   F =   8.4039229046013535
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           34     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.54210D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.49071D+00    |proj g|=  7.50270D-01
#
# At iterate    2    f=  8.44959D+00    |proj g|=  3.33115D-01
#
# At iterate    3    f=  8.44150D+00    |proj g|=  2.33189D-01
#
# At iterate    4    f=  8.43164D+00    |proj g|=  1.51531D-01
#
# At iterate    5    f=  8.42943D+00    |proj g|=  1.77155D-01
#
# At iterate    6    f=  8.42783D+00    |proj g|=  1.03462D-01
#
# At iterate    7    f=  8.42689D+00    |proj g|=  8.49639D-02
#
# At iterate    8    f=  8.42483D+00    |proj g|=  1.42833D-01
#
# At iterate    9    f=  8.42365D+00    |proj g|=  1.80715D-01
#
# At iterate   10    f=  8.42238D+00    |proj g|=  8.02679D-02
#
# At iterate   11    f=  8.42172D+00    |proj g|=  4.35042D-02
#
# At iterate   12    f=  8.42113D+00    |proj g|=  5.93040D-02
#
# At iterate   13    f=  8.42003D+00    |proj g|=  9.83285D-02
#
# At iterate   14    f=  8.41953D+00    |proj g|=  6.31223D-02
#
# At iterate   15    f=  8.41922D+00    |proj g|=  2.45471D-02
#
# At iterate   16    f=  8.41905D+00    |proj g|=  2.04455D-02
#
# At iterate   17    f=  8.41895D+00    |proj g|=  2.41631D-02
#
# At iterate   18    f=  8.41874D+00    |proj g|=  2.94115D-02
#
# At iterate   19    f=  8.41852D+00    |proj g|=  4.72383D-02
#
# At iterate   20    f=  8.41831D+00    |proj g|=  2.77190D-02
#
# At iterate   21    f=  8.41817D+00    |proj g|=  2.22498D-02
#
# At iterate   22    f=  8.41810D+00    |proj g|=  2.07136D-02
#
# At iterate   23    f=  8.41798D+00    |proj g|=  1.75204D-02
#
# At iterate   24    f=  8.41781D+00    |proj g|=  3.59893D-02
#
# At iterate   25    f=  8.41762D+00    |proj g|=  2.41080D-02
#
# At iterate   26    f=  8.41748D+00    |proj g|=  2.25750D-02
#
# At iterate   27    f=  8.41738D+00    |proj g|=  2.18495D-02
#
# At iterate   28    f=  8.41730D+00    |proj g|=  1.84455D-02
#
# At iterate   29    f=  8.41724D+00    |proj g|=  1.66949D-02
#
# At iterate   30    f=  8.41715D+00    |proj g|=  1.95834D-02
#
# At iterate   31    f=  8.41712D+00    |proj g|=  1.04869D-02
#
# At iterate   32    f=  8.41711D+00    |proj g|=  6.52491D-03
#
# At iterate   33    f=  8.41710D+00    |proj g|=  4.26965D-03
#
# At iterate   34    f=  8.41710D+00    |proj g|=  6.51745D-03
#
# At iterate   35    f=  8.41710D+00    |proj g|=  2.52740D-03
#
# At iterate   36    f=  8.41709D+00    |proj g|=  1.41114D-03
#
# At iterate   37    f=  8.41709D+00    |proj g|=  1.63745D-03
#
# At iterate   38    f=  8.41709D+00    |proj g|=  4.05507D-03
#
# At iterate   39    f=  8.41709D+00    |proj g|=  1.45342D-03
#
# At iterate   40    f=  8.41709D+00    |proj g|=  7.67031D-04
#
# At iterate   41    f=  8.41709D+00    |proj g|=  8.69349D-04
#
# At iterate   42    f=  8.41709D+00    |proj g|=  1.66835D-03
#
# At iterate   43    f=  8.41709D+00    |proj g|=  2.21672D-03
#
# At iterate   44    f=  8.41709D+00    |proj g|=  1.19744D-03
#
# At iterate   45    f=  8.41709D+00    |proj g|=  7.92788D-04
#
# At iterate   46    f=  8.41709D+00    |proj g|=  1.00773D-03
#
# At iterate   47    f=  8.41709D+00    |proj g|=  1.17168D-03
#
# At iterate   48    f=  8.41709D+00    |proj g|=  9.76641D-04
#
# At iterate   49    f=  8.41709D+00    |proj g|=  4.60432D-04
#
# At iterate   50    f=  8.41709D+00    |proj g|=  3.67351D-04
#
# At iterate   51    f=  8.41709D+00    |proj g|=  4.77485D-04
#
# At iterate   52    f=  8.41709D+00    |proj g|=  4.80505D-04
#
# At iterate   53    f=  8.41709D+00    |proj g|=  5.13367D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    34     53     58     57     0     2   5.134D-04   8.417D+00
#   F =   8.4170910824928669
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           95     M =           10
#
# At X0         1 variables are exactly at the bounds
#
# At iterate    0    f=  9.55358D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.34488D+00    |proj g|=  3.80208D-01
#
# At iterate    2    f=  8.30744D+00    |proj g|=  2.14454D-01
#
# At iterate    3    f=  8.29602D+00    |proj g|=  1.53197D-01
#
# At iterate    4    f=  8.28610D+00    |proj g|=  8.76451D-02
#
# At iterate    5    f=  8.28514D+00    |proj g|=  1.13208D-01
#
# At iterate    6    f=  8.28303D+00    |proj g|=  3.88809D-02
#
# At iterate    7    f=  8.28267D+00    |proj g|=  2.68585D-02
#
# At iterate    8    f=  8.28217D+00    |proj g|=  2.21222D-02
#
# At iterate    9    f=  8.28175D+00    |proj g|=  2.43205D-02
#
# At iterate   10    f=  8.28164D+00    |proj g|=  5.02418D-02
#
# At iterate   11    f=  8.28130D+00    |proj g|=  1.61064D-02
#
# At iterate   12    f=  8.28120D+00    |proj g|=  1.40773D-02
#
# At iterate   13    f=  8.28100D+00    |proj g|=  1.66375D-02
#
# At iterate   14    f=  8.28084D+00    |proj g|=  3.15401D-02
#
# At iterate   15    f=  8.28061D+00    |proj g|=  1.67841D-02
#
# At iterate   16    f=  8.28041D+00    |proj g|=  1.11234D-02
#
# At iterate   17    f=  8.28024D+00    |proj g|=  2.07921D-02
#
# At iterate   18    f=  8.28012D+00    |proj g|=  2.45057D-02
#
# At iterate   19    f=  8.27997D+00    |proj g|=  1.02119D-02
#
# At iterate   20    f=  8.27982D+00    |proj g|=  1.22737D-02
#
# At iterate   21    f=  8.27967D+00    |proj g|=  1.67514D-02
#
# At iterate   22    f=  8.27948D+00    |proj g|=  3.22013D-02
#
# At iterate   23    f=  8.27932D+00    |proj g|=  1.37302D-02
#
# At iterate   24    f=  8.27925D+00    |proj g|=  5.45910D-03
#
# At iterate   25    f=  8.27921D+00    |proj g|=  6.07905D-03
#
# At iterate   26    f=  8.27916D+00    |proj g|=  1.38332D-02
#
# At iterate   27    f=  8.27911D+00    |proj g|=  9.26832D-03
#
# At iterate   28    f=  8.27905D+00    |proj g|=  8.30429D-03
#
# At iterate   29    f=  8.27900D+00    |proj g|=  1.80624D-02
#
# At iterate   30    f=  8.27897D+00    |proj g|=  7.53513D-03
#
# At iterate   31    f=  8.27894D+00    |proj g|=  7.00915D-03
#
# At iterate   32    f=  8.27889D+00    |proj g|=  1.16458D-02
#
# At iterate   33    f=  8.27888D+00    |proj g|=  1.70315D-02
#
# At iterate   34    f=  8.27883D+00    |proj g|=  7.24185D-03
#
# At iterate   35    f=  8.27881D+00    |proj g|=  5.91189D-03
#
# At iterate   36    f=  8.27878D+00    |proj g|=  6.74287D-03
#
# At iterate   37    f=  8.27873D+00    |proj g|=  7.45963D-03
#
# At iterate   38    f=  8.27870D+00    |proj g|=  1.50044D-02
#
# At iterate   39    f=  8.27865D+00    |proj g|=  7.32356D-03
#
# At iterate   40    f=  8.27861D+00    |proj g|=  4.71214D-03
#
# At iterate   41    f=  8.27858D+00    |proj g|=  7.84510D-03
#
# At iterate   42    f=  8.27856D+00    |proj g|=  9.00204D-03
#
# At iterate   43    f=  8.27855D+00    |proj g|=  4.68585D-03
#
# At iterate   44    f=  8.27852D+00    |proj g|=  4.80540D-03
#
# At iterate   45    f=  8.27851D+00    |proj g|=  5.92397D-03
#
# At iterate   46    f=  8.27850D+00    |proj g|=  5.26956D-03
#
# At iterate   47    f=  8.27848D+00    |proj g|=  7.92344D-03
#
# At iterate   48    f=  8.27846D+00    |proj g|=  5.82538D-03
#
# At iterate   49    f=  8.27846D+00    |proj g|=  2.70042D-03
#
# At iterate   50    f=  8.27845D+00    |proj g|=  2.11564D-03
#
# At iterate   51    f=  8.27844D+00    |proj g|=  4.04530D-03
#
# At iterate   52    f=  8.27843D+00    |proj g|=  3.67031D-03
#
# At iterate   53    f=  8.27842D+00    |proj g|=  2.26503D-03
#
# At iterate   54    f=  8.27841D+00    |proj g|=  2.41300D-03
#
# At iterate   55    f=  8.27841D+00    |proj g|=  2.93312D-03
#
# At iterate   56    f=  8.27840D+00    |proj g|=  2.95959D-03
#
# At iterate   57    f=  8.27839D+00    |proj g|=  3.35820D-03
#
# At iterate   58    f=  8.27839D+00    |proj g|=  1.87406D-03
#
# At iterate   59    f=  8.27838D+00    |proj g|=  1.77653D-03
#
# At iterate   60    f=  8.27838D+00    |proj g|=  3.07026D-03
#
# At iterate   61    f=  8.27837D+00    |proj g|=  3.99130D-03
#
# At iterate   62    f=  8.27837D+00    |proj g|=  2.11848D-03
#
# At iterate   63    f=  8.27836D+00    |proj g|=  2.51958D-03
#
# At iterate   64    f=  8.27836D+00    |proj g|=  3.86731D-03
#
# At iterate   65    f=  8.27835D+00    |proj g|=  5.67280D-03
#
# At iterate   66    f=  8.27834D+00    |proj g|=  3.89004D-03
#
# At iterate   67    f=  8.27833D+00    |proj g|=  2.60041D-03
#
# At iterate   68    f=  8.27832D+00    |proj g|=  3.96199D-03
#
# At iterate   69    f=  8.27831D+00    |proj g|=  5.73941D-03
#
# At iterate   70    f=  8.27830D+00    |proj g|=  4.16414D-03
#
# At iterate   71    f=  8.27829D+00    |proj g|=  2.87255D-03
#
# At iterate   72    f=  8.27828D+00    |proj g|=  2.99796D-03
#
# At iterate   73    f=  8.27828D+00    |proj g|=  2.14815D-03
#
# At iterate   74    f=  8.27827D+00    |proj g|=  3.18359D-03
#
# At iterate   75    f=  8.27827D+00    |proj g|=  3.69216D-03
#
# At iterate   76    f=  8.27826D+00    |proj g|=  2.22702D-03
#
# At iterate   77    f=  8.27826D+00    |proj g|=  1.75078D-03
#
# At iterate   78    f=  8.27826D+00    |proj g|=  2.79190D-03
#
# At iterate   79    f=  8.27825D+00    |proj g|=  1.25233D-03
#
# At iterate   80    f=  8.27825D+00    |proj g|=  1.03686D-03
#
# At iterate   81    f=  8.27825D+00    |proj g|=  1.18003D-03
#
# At iterate   82    f=  8.27825D+00    |proj g|=  1.01625D-03
#
# At iterate   83    f=  8.27825D+00    |proj g|=  2.27693D-03
#
# At iterate   84    f=  8.27825D+00    |proj g|=  1.49107D-03
#
# At iterate   85    f=  8.27825D+00    |proj g|=  1.20473D-03
#
# At iterate   86    f=  8.27824D+00    |proj g|=  2.01421D-03
#
# At iterate   87    f=  8.27824D+00    |proj g|=  3.45999D-03
#
# At iterate   88    f=  8.27824D+00    |proj g|=  1.21076D-03
#
# At iterate   89    f=  8.27824D+00    |proj g|=  7.02371D-04
#
# At iterate   90    f=  8.27824D+00    |proj g|=  6.63114D-04
#
# At iterate   91    f=  8.27824D+00    |proj g|=  1.10667D-03
#
# At iterate   92    f=  8.27824D+00    |proj g|=  1.09974D-03
#
# At iterate   93    f=  8.27824D+00    |proj g|=  4.81926D-04
#
# At iterate   94    f=  8.27824D+00    |proj g|=  4.17621D-04
#
# At iterate   95    f=  8.27824D+00    |proj g|=  6.43041D-04
#
# At iterate   96    f=  8.27824D+00    |proj g|=  1.39622D-03
#
# At iterate   97    f=  8.27824D+00    |proj g|=  5.24025D-04
#
# At iterate   98    f=  8.27824D+00    |proj g|=  6.32205D-04
#
# At iterate   99    f=  8.27824D+00    |proj g|=  7.23865D-04
#
# At iterate  100    f=  8.27824D+00    |proj g|=  9.76641D-04
#
# At iterate  101    f=  8.27824D+00    |proj g|=  9.61187D-04
#
# At iterate  102    f=  8.27824D+00    |proj g|=  4.46931D-04
#
# At iterate  103    f=  8.27824D+00    |proj g|=  4.69669D-04
#
# At iterate  104    f=  8.27823D+00    |proj g|=  8.12861D-04
#
# At iterate  105    f=  8.27823D+00    |proj g|=  1.66036D-03
#
# At iterate  106    f=  8.27823D+00    |proj g|=  6.57785D-04
#
# At iterate  107    f=  8.27823D+00    |proj g|=  6.27765D-04
#
# At iterate  108    f=  8.27823D+00    |proj g|=  9.15534D-04
#
# At iterate  109    f=  8.27823D+00    |proj g|=  1.04450D-03
#
# At iterate  110    f=  8.27823D+00    |proj g|=  9.05231D-04
#
# At iterate  111    f=  8.27823D+00    |proj g|=  6.77325D-04
#
# At iterate  112    f=  8.27823D+00    |proj g|=  1.03224D-03
#
# At iterate  113    f=  8.27823D+00    |proj g|=  8.66329D-04
#
# At iterate  114    f=  8.27823D+00    |proj g|=  7.66676D-04
#
# At iterate  115    f=  8.27823D+00    |proj g|=  1.32481D-03
#
# At iterate  116    f=  8.27823D+00    |proj g|=  1.35731D-03
#
# At iterate  117    f=  8.27823D+00    |proj g|=  8.19966D-04
#
# At iterate  118    f=  8.27823D+00    |proj g|=  1.06137D-03
#
# At iterate  119    f=  8.27823D+00    |proj g|=  1.56497D-03
#
# At iterate  120    f=  8.27823D+00    |proj g|=  1.09655D-03
#
# At iterate  121    f=  8.27822D+00    |proj g|=  8.70060D-04
#
# At iterate  122    f=  8.27822D+00    |proj g|=  1.80371D-03
#
# At iterate  123    f=  8.27822D+00    |proj g|=  1.06350D-03
#
# At iterate  124    f=  8.27822D+00    |proj g|=  1.02904D-03
#
# At iterate  125    f=  8.27822D+00    |proj g|=  1.35891D-03
#
# At iterate  126    f=  8.27822D+00    |proj g|=  1.23244D-03
#
# At iterate  127    f=  8.27822D+00    |proj g|=  9.01323D-04
#
# At iterate  128    f=  8.27822D+00    |proj g|=  8.37908D-04
#
# At iterate  129    f=  8.27822D+00    |proj g|=  1.06919D-03
#
# At iterate  130    f=  8.27822D+00    |proj g|=  8.30447D-04
#
# At iterate  131    f=  8.27821D+00    |proj g|=  9.04876D-04
#
# At iterate  132    f=  8.27821D+00    |proj g|=  8.46434D-04
#
# At iterate  133    f=  8.27821D+00    |proj g|=  5.42322D-04
#
# At iterate  134    f=  8.27821D+00    |proj g|=  4.46576D-04
#
# At iterate  135    f=  8.27821D+00    |proj g|=  4.49063D-04
#
# At iterate  136    f=  8.27821D+00    |proj g|=  4.30944D-04
#
# At iterate  137    f=  8.27821D+00    |proj g|=  3.87068D-04
#
# At iterate  138    f=  8.27821D+00    |proj g|=  3.26494D-04
#
# At iterate  139    f=  8.27821D+00    |proj g|=  3.02336D-04
#
# At iterate  140    f=  8.27821D+00    |proj g|=  4.41602D-04
#
# At iterate  141    f=  8.27821D+00    |proj g|=  3.09974D-04
#
# At iterate  142    f=  8.27821D+00    |proj g|=  2.40519D-04
#
# At iterate  143    f=  8.27821D+00    |proj g|=  6.21370D-04
#
# At iterate  144    f=  8.27821D+00    |proj g|=  2.42473D-04
#
# At iterate  145    f=  8.27821D+00    |proj g|=  1.80655D-04
#
# At iterate  146    f=  8.27821D+00    |proj g|=  2.60414D-04
#
# At iterate  147    f=  8.27821D+00    |proj g|=  3.91154D-04
#
# At iterate  148    f=  8.27821D+00    |proj g|=  1.86517D-04
#
# At iterate  149    f=  8.27821D+00    |proj g|=  1.54543D-04
#
# At iterate  150    f=  8.27821D+00    |proj g|=  2.04636D-04
#
# At iterate  151    f=  8.27821D+00    |proj g|=  1.72662D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    95    151    157    156     0     2   1.727D-04   8.278D+00
#   F =   8.2782123213262437
#
# STOP: TOTAL NO. of f AND g EVALUATIONS EXCEEDS LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           94     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.63191D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.35461D+00    |proj g|=  3.80847D-01
#
# At iterate    2    f=  8.31323D+00    |proj g|=  1.57453D-01
#
# At iterate    3    f=  8.30062D+00    |proj g|=  9.51983D-02
#
# At iterate    4    f=  8.29300D+00    |proj g|=  6.33801D-02
#
# At iterate    5    f=  8.29158D+00    |proj g|=  1.01288D-01
#
# At iterate    6    f=  8.28982D+00    |proj g|=  3.40703D-02
#
# At iterate    7    f=  8.28942D+00    |proj g|=  2.57902D-02
#
# At iterate    8    f=  8.28897D+00    |proj g|=  1.98572D-02
#
# At iterate    9    f=  8.28850D+00    |proj g|=  2.29377D-02
#
# At iterate   10    f=  8.28826D+00    |proj g|=  4.26855D-02
#
# At iterate   11    f=  8.28788D+00    |proj g|=  1.68530D-02
#
# At iterate   12    f=  8.28769D+00    |proj g|=  1.37664D-02
#
# At iterate   13    f=  8.28745D+00    |proj g|=  1.75360D-02
#
# At iterate   14    f=  8.28714D+00    |proj g|=  3.08708D-02
#
# At iterate   15    f=  8.28684D+00    |proj g|=  1.50591D-02
#
# At iterate   16    f=  8.28667D+00    |proj g|=  9.58629D-03
#
# At iterate   17    f=  8.28648D+00    |proj g|=  1.83999D-02
#
# At iterate   18    f=  8.28636D+00    |proj g|=  2.05116D-02
#
# At iterate   19    f=  8.28625D+00    |proj g|=  1.24430D-02
#
# At iterate   20    f=  8.28603D+00    |proj g|=  1.19911D-02
#
# At iterate   21    f=  8.28598D+00    |proj g|=  1.84238D-02
#
# At iterate   22    f=  8.28591D+00    |proj g|=  1.00579D-02
#
# At iterate   23    f=  8.28583D+00    |proj g|=  7.77796D-03
#
# At iterate   24    f=  8.28578D+00    |proj g|=  1.02748D-02
#
# At iterate   25    f=  8.28566D+00    |proj g|=  2.44075D-02
#
# At iterate   26    f=  8.28554D+00    |proj g|=  1.41027D-02
#
# At iterate   27    f=  8.28547D+00    |proj g|=  7.76037D-03
#
# At iterate   28    f=  8.28538D+00    |proj g|=  1.08349D-02
#
# At iterate   29    f=  8.28534D+00    |proj g|=  2.00126D-02
#
# At iterate   30    f=  8.28530D+00    |proj g|=  1.19751D-02
#
# At iterate   31    f=  8.28521D+00    |proj g|=  9.54365D-03
#
# At iterate   32    f=  8.28517D+00    |proj g|=  8.58442D-03
#
# At iterate   33    f=  8.28513D+00    |proj g|=  1.45786D-02
#
# At iterate   34    f=  8.28507D+00    |proj g|=  5.26157D-03
#
# At iterate   35    f=  8.28504D+00    |proj g|=  4.98996D-03
#
# At iterate   36    f=  8.28501D+00    |proj g|=  1.16625D-02
#
# At iterate   37    f=  8.28499D+00    |proj g|=  6.91749D-03
#
# At iterate   38    f=  8.28497D+00    |proj g|=  4.89866D-03
#
# At iterate   39    f=  8.28495D+00    |proj g|=  4.21121D-03
#
# At iterate   40    f=  8.28494D+00    |proj g|=  7.70637D-03
#
# At iterate   41    f=  8.28491D+00    |proj g|=  4.31832D-03
#
# At iterate   42    f=  8.28489D+00    |proj g|=  7.39604D-03
#
# At iterate   43    f=  8.28488D+00    |proj g|=  5.49054D-03
#
# At iterate   44    f=  8.28487D+00    |proj g|=  4.12577D-03
#
# At iterate   45    f=  8.28485D+00    |proj g|=  2.85674D-03
#
# At iterate   46    f=  8.28484D+00    |proj g|=  7.12141D-03
#
# At iterate   47    f=  8.28483D+00    |proj g|=  3.35874D-03
#
# At iterate   48    f=  8.28482D+00    |proj g|=  3.37561D-03
#
# At iterate   49    f=  8.28481D+00    |proj g|=  3.93108D-03
#
# At iterate   50    f=  8.28480D+00    |proj g|=  9.18376D-03
#
# At iterate   51    f=  8.28478D+00    |proj g|=  3.80780D-03
#
# At iterate   52    f=  8.28477D+00    |proj g|=  3.17719D-03
#
# At iterate   53    f=  8.28476D+00    |proj g|=  3.26086D-03
#
# At iterate   54    f=  8.28475D+00    |proj g|=  9.53904D-03
#
# At iterate   55    f=  8.28474D+00    |proj g|=  3.78826D-03
#
# At iterate   56    f=  8.28473D+00    |proj g|=  2.13394D-03
#
# At iterate   57    f=  8.28472D+00    |proj g|=  4.00071D-03
#
# At iterate   58    f=  8.28471D+00    |proj g|=  6.46594D-03
#
# At iterate   59    f=  8.28471D+00    |proj g|=  3.36406D-03
#
# At iterate   60    f=  8.28470D+00    |proj g|=  1.78861D-03
#
# At iterate   61    f=  8.28470D+00    |proj g|=  3.02105D-03
#
# At iterate   62    f=  8.28469D+00    |proj g|=  2.33804D-03
#
# At iterate   63    f=  8.28469D+00    |proj g|=  1.72200D-03
#
# At iterate   64    f=  8.28469D+00    |proj g|=  3.32161D-03
#
# At iterate   65    f=  8.28468D+00    |proj g|=  2.35865D-03
#
# At iterate   66    f=  8.28468D+00    |proj g|=  1.31681D-03
#
# At iterate   67    f=  8.28468D+00    |proj g|=  8.79652D-04
#
# At iterate   68    f=  8.28468D+00    |proj g|=  1.64651D-03
#
# At iterate   69    f=  8.28468D+00    |proj g|=  1.11715D-03
#
# At iterate   70    f=  8.28468D+00    |proj g|=  8.13394D-04
#
# At iterate   71    f=  8.28468D+00    |proj g|=  1.15001D-03
#
# At iterate   72    f=  8.28468D+00    |proj g|=  9.51417D-04
#
# At iterate   73    f=  8.28468D+00    |proj g|=  1.00222D-03
#
# At iterate   74    f=  8.28468D+00    |proj g|=  1.71347D-03
#
# At iterate   75    f=  8.28468D+00    |proj g|=  8.99014D-04
#
# At iterate   76    f=  8.28467D+00    |proj g|=  5.89218D-04
#
# At iterate   77    f=  8.28467D+00    |proj g|=  6.60094D-04
#
# At iterate   78    f=  8.28467D+00    |proj g|=  1.84510D-03
#
# At iterate   79    f=  8.28467D+00    |proj g|=  1.09637D-03
#
# At iterate   80    f=  8.28467D+00    |proj g|=  7.13030D-04
#
# At iterate   81    f=  8.28467D+00    |proj g|=  1.10347D-03
#
# At iterate   82    f=  8.28467D+00    |proj g|=  1.26583D-03
#
# At iterate   83    f=  8.28467D+00    |proj g|=  2.57945D-03
#
# At iterate   84    f=  8.28467D+00    |proj g|=  1.26672D-03
#
# At iterate   85    f=  8.28467D+00    |proj g|=  6.06093D-04
#
# At iterate   86    f=  8.28467D+00    |proj g|=  1.04681D-03
#
# At iterate   87    f=  8.28467D+00    |proj g|=  1.13474D-03
#
# At iterate   88    f=  8.28467D+00    |proj g|=  6.43396D-04
#
# At iterate   89    f=  8.28467D+00    |proj g|=  9.62252D-04
#
# At iterate   90    f=  8.28467D+00    |proj g|=  9.89964D-04
#
# At iterate   91    f=  8.28467D+00    |proj g|=  7.27063D-04
#
# At iterate   92    f=  8.28466D+00    |proj g|=  7.84084D-04
#
# At iterate   93    f=  8.28466D+00    |proj g|=  1.59392D-03
#
# At iterate   94    f=  8.28466D+00    |proj g|=  9.32587D-04
#
# At iterate   95    f=  8.28466D+00    |proj g|=  5.37170D-04
#
# At iterate   96    f=  8.28466D+00    |proj g|=  6.07869D-04
#
# At iterate   97    f=  8.28466D+00    |proj g|=  8.32401D-04
#
# At iterate   98    f=  8.28466D+00    |proj g|=  1.98828D-03
#
# At iterate   99    f=  8.28466D+00    |proj g|=  1.25873D-03
#
# At iterate  100    f=  8.28466D+00    |proj g|=  5.43565D-04
#
# At iterate  101    f=  8.28466D+00    |proj g|=  6.73595D-04
#
# At iterate  102    f=  8.28466D+00    |proj g|=  1.59854D-03
#
# At iterate  103    f=  8.28466D+00    |proj g|=  7.49267D-04
#
# At iterate  104    f=  8.28466D+00    |proj g|=  3.92397D-04
#
# At iterate  105    f=  8.28466D+00    |proj g|=  3.65397D-04
#
# At iterate  106    f=  8.28466D+00    |proj g|=  6.56009D-04
#
# At iterate  107    f=  8.28466D+00    |proj g|=  7.25642D-04
#
# At iterate  108    f=  8.28466D+00    |proj g|=  3.70903D-04
#
# At iterate  109    f=  8.28466D+00    |proj g|=  3.77476D-04
#
# At iterate  110    f=  8.28466D+00    |proj g|=  4.91696D-04
#
# At iterate  111    f=  8.28466D+00    |proj g|=  1.05889D-03
#
# At iterate  112    f=  8.28466D+00    |proj g|=  1.11271D-03
#
# At iterate  113    f=  8.28466D+00    |proj g|=  6.35403D-04
#
# At iterate  114    f=  8.28466D+00    |proj g|=  5.65237D-04
#
# At iterate  115    f=  8.28465D+00    |proj g|=  6.44107D-04
#
# At iterate  116    f=  8.28465D+00    |proj g|=  4.71445D-04
#
# At iterate  117    f=  8.28465D+00    |proj g|=  4.74287D-04
#
# At iterate  118    f=  8.28465D+00    |proj g|=  5.21716D-04
#
# At iterate  119    f=  8.28465D+00    |proj g|=  5.80336D-04
#
# At iterate  120    f=  8.28465D+00    |proj g|=  2.83329D-04
#
# At iterate  121    f=  8.28465D+00    |proj g|=  2.96474D-04
#
# At iterate  122    f=  8.28465D+00    |proj g|=  4.61142D-04
#
# At iterate  123    f=  8.28465D+00    |proj g|=  3.33245D-04
#
# At iterate  124    f=  8.28465D+00    |proj g|=  9.01323D-04
#
# At iterate  125    f=  8.28465D+00    |proj g|=  2.74092D-04
#
# At iterate  126    f=  8.28465D+00    |proj g|=  1.99485D-04
#
# At iterate  127    f=  8.28465D+00    |proj g|=  2.13518D-04
#
# At iterate  128    f=  8.28465D+00    |proj g|=  2.67697D-04
#
# At iterate  129    f=  8.28465D+00    |proj g|=  1.55076D-04
#
# At iterate  130    f=  8.28465D+00    |proj g|=  1.26477D-04
#
# At iterate  131    f=  8.28465D+00    |proj g|=  1.94511D-04
#
# At iterate  132    f=  8.28465D+00    |proj g|=  1.14753D-04
#
# At iterate  133    f=  8.28465D+00    |proj g|=  1.39089D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    94    133    138    137     0     2   1.391D-04   8.285D+00
#   F =   8.2846526958860611
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         1 variables are exactly at the bounds
#
# At iterate    0    f=  9.47899D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.48469D+00    |proj g|=  2.00420D-01
#
# At iterate    2    f=  8.47956D+00    |proj g|=  1.17263D-01
#
# At iterate    3    f=  8.47616D+00    |proj g|=  3.15474D-02
#
# At iterate    4    f=  8.47584D+00    |proj g|=  6.66880D-03
#
# At iterate    5    f=  8.47581D+00    |proj g|=  5.46016D-03
#
# At iterate    6    f=  8.47579D+00    |proj g|=  2.21743D-03
#
# At iterate    7    f=  8.47578D+00    |proj g|=  1.92752D-03
#
# At iterate    8    f=  8.47577D+00    |proj g|=  5.08038D-04
#
# At iterate    9    f=  8.47577D+00    |proj g|=  3.01981D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      9     10     13     0     2   3.020D-06   8.476D+00
#   F =   8.4757735860099572
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.55296D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.49003D+00    |proj g|=  9.99800D-01
#
# At iterate    2    f=  8.48663D+00    |proj g|=  2.42205D-02
#
# At iterate    3    f=  8.48629D+00    |proj g|=  1.89538D-02
#
# At iterate    4    f=  8.48613D+00    |proj g|=  2.04158D-02
#
# At iterate    5    f=  8.48610D+00    |proj g|=  2.54197D-04
#
# At iterate    6    f=  8.48610D+00    |proj g|=  2.27374D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      6     11      8     0     1   2.274D-05   8.486D+00
#   F =   8.4860985114758574
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         1 variables are exactly at the bounds
#
# At iterate    0    f=  9.47899D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.48469D+00    |proj g|=  2.00420D-01
#
# At iterate    2    f=  8.47956D+00    |proj g|=  1.17263D-01
#
# At iterate    3    f=  8.47616D+00    |proj g|=  3.15474D-02
#
# At iterate    4    f=  8.47584D+00    |proj g|=  6.66880D-03
#
# At iterate    5    f=  8.47581D+00    |proj g|=  5.46016D-03
#
# At iterate    6    f=  8.47579D+00    |proj g|=  2.21743D-03
#
# At iterate    7    f=  8.47578D+00    |proj g|=  1.92752D-03
#
# At iterate    8    f=  8.47577D+00    |proj g|=  5.08038D-04
#
# At iterate    9    f=  8.47577D+00    |proj g|=  3.01981D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      9     10     13     0     2   3.020D-06   8.476D+00
#   F =   8.4757735860099572
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.55296D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.49003D+00    |proj g|=  9.99800D-01
#
# At iterate    2    f=  8.48663D+00    |proj g|=  2.42205D-02
#
# At iterate    3    f=  8.48629D+00    |proj g|=  1.89538D-02
#
# At iterate    4    f=  8.48613D+00    |proj g|=  2.04158D-02
#
# At iterate    5    f=  8.48610D+00    |proj g|=  2.54197D-04
#
# At iterate    6    f=  8.48610D+00    |proj g|=  2.27374D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      6     11      8     0     1   2.274D-05   8.486D+00
#   F =   8.4860985114758574
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         1 variables are exactly at the bounds
#
# At iterate    0    f=  9.47899D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  8.48469D+00    |proj g|=  2.00420D-01
#
# At iterate    2    f=  8.47956D+00    |proj g|=  1.17263D-01
#
# At iterate    3    f=  8.47616D+00    |proj g|=  3.15474D-02
#
# At iterate    4    f=  8.47584D+00    |proj g|=  6.66880D-03
#
# At iterate    5    f=  8.47581D+00    |proj g|=  5.46016D-03
#
# At iterate    6    f=  8.47579D+00    |proj g|=  2.21743D-03
#
# At iterate    7    f=  8.47578D+00    |proj g|=  1.92752D-03
#
# At iterate    8    f=  8.47577D+00    |proj g|=  5.08038D-04
#
# At iterate    9    f=  8.47577D+00    |proj g|=  3.01981D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      9     10     13     0     2   3.020D-06   8.476D+00
#   F =   8.4757735860099572
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
# ...
#   Positive dir derivative in projection
#   Using the backtracking step
#
# At iterate   11    f=  7.70779D+00    |proj g|=  3.31850D-01
#   ys=-9.398E-05  -gs= 5.523E-04 BFGS update SKIPPED
#
# At iterate   12    f=  7.70761D+00    |proj g|=  2.03876D-01
#
# At iterate   13    f=  7.70751D+00    |proj g|=  7.14228D-02
#
# At iterate   14    f=  7.70749D+00    |proj g|=  4.09630D-02
#
# At iterate   15    f=  7.70749D+00    |proj g|=  2.72212D-02
#
# At iterate   16    f=  7.70748D+00    |proj g|=  2.07648D-02
#
# At iterate   17    f=  7.70748D+00    |proj g|=  8.13660D-04
#
# At iterate   18    f=  7.70748D+00    |proj g|=  6.14442D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     9     18     29     22     1     1   6.144D-04   7.707D+00
#   F =   7.7074817100180626
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           32     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.76314D+00    |proj g|=  9.51312D-01
#
# At iterate    1    f=  7.85221D+00    |proj g|=  2.41566D-01
#
# At iterate    2    f=  7.79603D+00    |proj g|=  1.76042D-01
#
# At iterate    3    f=  7.75152D+00    |proj g|=  1.06602D-01
#
# At iterate    4    f=  7.73165D+00    |proj g|=  1.25749D-01
#
# At iterate    5    f=  7.72457D+00    |proj g|=  1.50482D-01
#
# At iterate    6    f=  7.72123D+00    |proj g|=  2.85206D-01
#
# At iterate    7    f=  7.70775D+00    |proj g|=  4.50127D-01
#
# At iterate    8    f=  7.70484D+00    |proj g|=  2.36037D-01
#
# At iterate    9    f=  7.70347D+00    |proj g|=  2.01327D-01
#
# At iterate   10    f=  7.70298D+00    |proj g|=  1.30628D-01
#
# At iterate   11    f=  7.70220D+00    |proj g|=  6.92453D-02
#
# At iterate   12    f=  7.70175D+00    |proj g|=  6.88418D-02
#
# At iterate   13    f=  7.70140D+00    |proj g|=  5.60020D-02
#
# At iterate   14    f=  7.70116D+00    |proj g|=  5.54492D-02
#
# At iterate   15    f=  7.70097D+00    |proj g|=  4.41655D-02
#
# At iterate   16    f=  7.70083D+00    |proj g|=  4.27778D-02
#
# At iterate   17    f=  7.70057D+00    |proj g|=  4.72194D-02
#
# At iterate   18    f=  7.70041D+00    |proj g|=  7.35110D-02
#
# At iterate   19    f=  7.70024D+00    |proj g|=  3.22419D-02
#
# At iterate   20    f=  7.70016D+00    |proj g|=  2.01009D-02
#
# At iterate   21    f=  7.70013D+00    |proj g|=  2.41481D-02
#
# At iterate   22    f=  7.70009D+00    |proj g|=  2.11779D-02
#
# At iterate   23    f=  7.70003D+00    |proj g|=  1.86933D-02
#
# At iterate   24    f=  7.69999D+00    |proj g|=  2.55668D-02
#
# At iterate   25    f=  7.69995D+00    |proj g|=  1.51829D-02
#
# At iterate   26    f=  7.69993D+00    |proj g|=  9.65086D-03
#
# At iterate   27    f=  7.69992D+00    |proj g|=  1.17158D-02
#
# At iterate   28    f=  7.69990D+00    |proj g|=  2.44968D-02
#
# At iterate   29    f=  7.69988D+00    |proj g|=  9.42304D-03
#
# At iterate   30    f=  7.69986D+00    |proj g|=  1.40221D-02
#
# At iterate   31    f=  7.69983D+00    |proj g|=  2.19453D-02
#
# At iterate   32    f=  7.69978D+00    |proj g|=  2.51391D-02
#
# At iterate   33    f=  7.69975D+00    |proj g|=  3.15088D-02
#
# At iterate   34    f=  7.69972D+00    |proj g|=  1.30424D-02
#
# At iterate   35    f=  7.69971D+00    |proj g|=  5.92602D-03
#
# At iterate   36    f=  7.69971D+00    |proj g|=  4.29097D-03
#
# At iterate   37    f=  7.69971D+00    |proj g|=  7.48983D-03
#
# At iterate   38    f=  7.69971D+00    |proj g|=  2.75016D-03
#
# At iterate   39    f=  7.69971D+00    |proj g|=  1.47145D-03
#
# At iterate   40    f=  7.69971D+00    |proj g|=  7.64366D-04
#
# At iterate   41    f=  7.69971D+00    |proj g|=  1.08482D-03
#
# At iterate   42    f=  7.69971D+00    |proj g|=  5.19051D-04
#
# At iterate   43    f=  7.69971D+00    |proj g|=  4.79794D-04
#
# At iterate   44    f=  7.69971D+00    |proj g|=  7.98739D-04
#
# At iterate   45    f=  7.69971D+00    |proj g|=  9.58256D-04
#
# At iterate   46    f=  7.69971D+00    |proj g|=  1.29265D-03
#
# At iterate   47    f=  7.69971D+00    |proj g|=  6.22524D-04
#
# At iterate   48    f=  7.69971D+00    |proj g|=  2.42828D-04
#
# At iterate   49    f=  7.69971D+00    |proj g|=  2.59792D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    32     49     58     51     0     1   2.598D-04   7.700D+00
#   F =   7.6997074992674115
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           92     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.79217D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  7.70548D+00    |proj g|=  1.66152D-01
#
# At iterate    2    f=  7.69532D+00    |proj g|=  7.28143D-02
#
# At iterate    3    f=  7.68672D+00    |proj g|=  1.19658D-01
#
# At iterate    4    f=  7.68442D+00    |proj g|=  4.98367D-02
#
# At iterate    5    f=  7.68379D+00    |proj g|=  2.98881D-02
#
# At iterate    6    f=  7.68349D+00    |proj g|=  3.04604D-02
#
# At iterate    7    f=  7.68308D+00    |proj g|=  2.91803D-02
#
# At iterate    8    f=  7.68287D+00    |proj g|=  3.51823D-02
#
# At iterate    9    f=  7.68266D+00    |proj g|=  1.57229D-02
#
# At iterate   10    f=  7.68258D+00    |proj g|=  1.29911D-02
#
# At iterate   11    f=  7.68250D+00    |proj g|=  1.08638D-02
#
# At iterate   12    f=  7.68241D+00    |proj g|=  1.65071D-02
#
# At iterate   13    f=  7.68234D+00    |proj g|=  1.19624D-02
#
# At iterate   14    f=  7.68230D+00    |proj g|=  1.00391D-02
#
# At iterate   15    f=  7.68226D+00    |proj g|=  6.85088D-03
#
# At iterate   16    f=  7.68223D+00    |proj g|=  1.28090D-02
#
# At iterate   17    f=  7.68220D+00    |proj g|=  6.43565D-03
#
# At iterate   18    f=  7.68216D+00    |proj g|=  7.88720D-03
#
# At iterate   19    f=  7.68213D+00    |proj g|=  1.02392D-02
#
# At iterate   20    f=  7.68209D+00    |proj g|=  8.44480D-03
#
# At iterate   21    f=  7.68203D+00    |proj g|=  1.19152D-02
#
# At iterate   22    f=  7.68198D+00    |proj g|=  7.86811D-03
#
# At iterate   23    f=  7.68195D+00    |proj g|=  6.46292D-03
#
# At iterate   24    f=  7.68190D+00    |proj g|=  7.93996D-03
#
# At iterate   25    f=  7.68188D+00    |proj g|=  1.65971D-02
#
# At iterate   26    f=  7.68185D+00    |proj g|=  6.64340D-03
#
# At iterate   27    f=  7.68183D+00    |proj g|=  4.88241D-03
#
# At iterate   28    f=  7.68181D+00    |proj g|=  5.41158D-03
#
# At iterate   29    f=  7.68177D+00    |proj g|=  5.38298D-03
#
# At iterate   30    f=  7.68176D+00    |proj g|=  9.68923D-03
#
# At iterate   31    f=  7.68173D+00    |proj g|=  5.75859D-03
#
# At iterate   32    f=  7.68171D+00    |proj g|=  4.81437D-03
#
# At iterate   33    f=  7.68169D+00    |proj g|=  8.92548D-03
#
# At iterate   34    f=  7.68167D+00    |proj g|=  8.75513D-03
#
# At iterate   35    f=  7.68166D+00    |proj g|=  4.65032D-03
#
# At iterate   36    f=  7.68165D+00    |proj g|=  4.16671D-03
#
# At iterate   37    f=  7.68164D+00    |proj g|=  4.56577D-03
#
# At iterate   38    f=  7.68163D+00    |proj g|=  8.17666D-03
#
# At iterate   39    f=  7.68162D+00    |proj g|=  2.83897D-03
#
# At iterate   40    f=  7.68161D+00    |proj g|=  1.98312D-03
#
# At iterate   41    f=  7.68161D+00    |proj g|=  3.83000D-03
#
# At iterate   42    f=  7.68160D+00    |proj g|=  4.67804D-03
#
# At iterate   43    f=  7.68159D+00    |proj g|=  3.00577D-03
#
# At iterate   44    f=  7.68159D+00    |proj g|=  4.89990D-03
#
# At iterate   45    f=  7.68158D+00    |proj g|=  4.32276D-03
#
# At iterate   46    f=  7.68158D+00    |proj g|=  3.24505D-03
#
# At iterate   47    f=  7.68157D+00    |proj g|=  2.91065D-03
#
# At iterate   48    f=  7.68157D+00    |proj g|=  4.38316D-03
#
# At iterate   49    f=  7.68157D+00    |proj g|=  1.78364D-03
#
# At iterate   50    f=  7.68156D+00    |proj g|=  1.58238D-03
#
# At iterate   51    f=  7.68156D+00    |proj g|=  1.56417D-03
#
# At iterate   52    f=  7.68156D+00    |proj g|=  2.41922D-03
#
# At iterate   53    f=  7.68156D+00    |proj g|=  3.56541D-03
#
# At iterate   54    f=  7.68156D+00    |proj g|=  1.28688D-03
#
# At iterate   55    f=  7.68156D+00    |proj g|=  1.09441D-03
#
# At iterate   56    f=  7.68155D+00    |proj g|=  1.83764D-03
#
# At iterate   57    f=  7.68155D+00    |proj g|=  2.48663D-03
#
# At iterate   58    f=  7.68155D+00    |proj g|=  8.80540D-04
#
# At iterate   59    f=  7.68155D+00    |proj g|=  6.57163D-04
#
# At iterate   60    f=  7.68155D+00    |proj g|=  8.44658D-04
#
# At iterate   61    f=  7.68155D+00    |proj g|=  1.09672D-03
#
# At iterate   62    f=  7.68155D+00    |proj g|=  1.59153D-03
#
# At iterate   63    f=  7.68155D+00    |proj g|=  7.24221D-04
#
# At iterate   64    f=  7.68155D+00    |proj g|=  5.13101D-04
#
# At iterate   65    f=  7.68155D+00    |proj g|=  6.67999D-04
#
# At iterate   66    f=  7.68155D+00    |proj g|=  1.30509D-03
#
# At iterate   67    f=  7.68155D+00    |proj g|=  1.09068D-03
#
# At iterate   68    f=  7.68155D+00    |proj g|=  9.32943D-04
#
# At iterate   69    f=  7.68155D+00    |proj g|=  1.28697D-03
#
# At iterate   70    f=  7.68155D+00    |proj g|=  6.09912D-04
#
# At iterate   71    f=  7.68155D+00    |proj g|=  7.07878D-04
#
# At iterate   72    f=  7.68155D+00    |proj g|=  8.44658D-04
#
# At iterate   73    f=  7.68155D+00    |proj g|=  7.91456D-04
#
# At iterate   74    f=  7.68155D+00    |proj g|=  6.52012D-04
#
# At iterate   75    f=  7.68155D+00    |proj g|=  8.01581D-04
#
# At iterate   76    f=  7.68155D+00    |proj g|=  6.14886D-04
#
# At iterate   77    f=  7.68155D+00    |proj g|=  4.81748D-04
#
# At iterate   78    f=  7.68155D+00    |proj g|=  5.83888D-04
#
# At iterate   79    f=  7.68155D+00    |proj g|=  1.06741D-03
#
# At iterate   80    f=  7.68155D+00    |proj g|=  4.55902D-04
#
# At iterate   81    f=  7.68155D+00    |proj g|=  6.06093D-04
#
# At iterate   82    f=  7.68155D+00    |proj g|=  5.77582D-04
#
# At iterate   83    f=  7.68154D+00    |proj g|=  1.55742D-03
#
# At iterate   84    f=  7.68154D+00    |proj g|=  5.93925D-04
#
# At iterate   85    f=  7.68154D+00    |proj g|=  4.29790D-04
#
# At iterate   86    f=  7.68154D+00    |proj g|=  6.52900D-04
#
# At iterate   87    f=  7.68154D+00    |proj g|=  1.17426D-03
#
# At iterate   88    f=  7.68154D+00    |proj g|=  9.31610D-04
#
# At iterate   89    f=  7.68154D+00    |proj g|=  1.16982D-03
#
# At iterate   90    f=  7.68154D+00    |proj g|=  1.50946D-03
#
# At iterate   91    f=  7.68154D+00    |proj g|=  9.89964D-04
#
# At iterate   92    f=  7.68154D+00    |proj g|=  8.29559D-04
#
# At iterate   93    f=  7.68154D+00    |proj g|=  1.35456D-03
#
# At iterate   94    f=  7.68154D+00    |proj g|=  9.44045D-04
#
# At iterate   95    f=  7.68154D+00    |proj g|=  1.11662D-03
#
# At iterate   96    f=  7.68154D+00    |proj g|=  9.29656D-04
#
# At iterate   97    f=  7.68154D+00    |proj g|=  7.51577D-04
#
# At iterate   98    f=  7.68154D+00    |proj g|=  6.13465D-04
#
# At iterate   99    f=  7.68154D+00    |proj g|=  1.05871D-03
#
# At iterate  100    f=  7.68154D+00    |proj g|=  5.19407D-04
#
# At iterate  101    f=  7.68154D+00    |proj g|=  5.00755D-04
#
# At iterate  102    f=  7.68154D+00    |proj g|=  7.02283D-04
#
# At iterate  103    f=  7.68154D+00    |proj g|=  8.83116D-04
#
# At iterate  104    f=  7.68154D+00    |proj g|=  1.41274D-03
#
# At iterate  105    f=  7.68154D+00    |proj g|=  5.13278D-04
#
# At iterate  106    f=  7.68154D+00    |proj g|=  3.68594D-04
#
# At iterate  107    f=  7.68154D+00    |proj g|=  4.59899D-04
#
# At iterate  108    f=  7.68154D+00    |proj g|=  5.43210D-04
#
# At iterate  109    f=  7.68154D+00    |proj g|=  1.37845D-04
#
# At iterate  110    f=  7.68154D+00    |proj g|=  9.22817D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    92    110    116    112     0     1   9.228D-05   7.682D+00
#   F =   7.6815370527673439
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.73415D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  7.70642D+00    |proj g|=  1.50978D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1      2      2     0     1   1.510D-06   7.706D+00
#   F =   7.7064159959568492
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.73415D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  7.70642D+00    |proj g|=  1.50978D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1      2      2     0     1   1.510D-06   7.706D+00
#   F =   7.7064159959568492
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  8.73415D+00    |proj g|=  8.99900D-01
#
# At iterate    1    f=  7.70642D+00    |proj g|=  1.50978D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1      2      2     0     1   1.510D-06   7.706D+00
#   F =   7.7064159959568492
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#                       (e, t, s)           AIC         MAE
# 0     (mul, add, mul, 90, True)  24728.491519    0.023970
# 1    (mul, mul, mul, 90, False)  24740.639760    0.023971
# 2   (mul, None, mul, 90, False)  24738.192421    0.023972
# 3     (mul, mul, mul, 90, True)  24726.009088    0.023982
# 4    (mul, add, mul, 90, False)  24744.544914    0.024043
# ..                          ...           ...         ...
# 85  (add, None, add, 30, False)  27224.178738  658.163069
# 86   (add, add, add, 30, False)  27228.837769  658.740865
# 87    (add, add, add, 30, True)  27218.247580  665.945369
# 88    (add, mul, add, 30, True)  27220.407810  666.298690
# 89   (add, mul, add, 30, False)  27240.529282  668.452736
#
# [90 rows x 3 columns]

# %%
model = ETSModel(
    train_data['Price'],
    error="mul",
    trend="add",
    seasonal="mul",
    damped_trend=True,
    seasonal_periods=90)

res = model.fit()
print(res.summary())
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           95     M =           10
#
# At X0         1 variables are exactly at the bounds
#
# At iterate    0    f=  8.66150D+00    |proj g|=  9.88789D-01
#
# At iterate    1    f=  7.84417D+00    |proj g|=  3.39608D-01
#
# At iterate    2    f=  7.76024D+00    |proj g|=  2.27014D-01
#
# At iterate    3    f=  7.70741D+00    |proj g|=  1.20773D-01
#
# At iterate    4    f=  7.68747D+00    |proj g|=  1.13316D-01
#
# At iterate    5    f=  7.67929D+00    |proj g|=  7.90386D-02
#
# At iterate    6    f=  7.67596D+00    |proj g|=  1.83571D-01
#
# At iterate    7    f=  7.66523D+00    |proj g|=  2.11642D-01
#
# At iterate    8    f=  7.66297D+00    |proj g|=  1.93663D-01
#
# At iterate    9    f=  7.65885D+00    |proj g|=  9.31113D-02
#
# At iterate   10    f=  7.65754D+00    |proj g|=  5.27558D-02
#
# At iterate   11    f=  7.65651D+00    |proj g|=  4.63893D-02
#
# At iterate   12    f=  7.65618D+00    |proj g|=  9.30241D-02
#
# At iterate   13    f=  7.65554D+00    |proj g|=  2.44174D-02
#
# At iterate   14    f=  7.65540D+00    |proj g|=  1.71429D-02
#
# At iterate   15    f=  7.65502D+00    |proj g|=  1.77000D-02
#
# At iterate   16    f=  7.65485D+00    |proj g|=  2.69625D-02
#
# At iterate   17    f=  7.65470D+00    |proj g|=  1.60782D-02
#
# At iterate   18    f=  7.65451D+00    |proj g|=  1.66819D-02
#
# At iterate   19    f=  7.65434D+00    |proj g|=  2.70353D-02
#
# At iterate   20    f=  7.65417D+00    |proj g|=  1.33666D-02
#
# At iterate   21    f=  7.65403D+00    |proj g|=  1.44895D-02
#
# At iterate   22    f=  7.65396D+00    |proj g|=  1.07820D-02
#
# At iterate   23    f=  7.65390D+00    |proj g|=  9.64517D-03
#
# At iterate   24    f=  7.65386D+00    |proj g|=  1.67464D-02
#
# At iterate   25    f=  7.65383D+00    |proj g|=  1.10471D-02
#
# At iterate   26    f=  7.65381D+00    |proj g|=  7.88463D-03
#
# At iterate   27    f=  7.65375D+00    |proj g|=  6.18670D-03
#
# At iterate   28    f=  7.65371D+00    |proj g|=  1.21767D-02
#
# At iterate   29    f=  7.65368D+00    |proj g|=  8.16920D-03
#
# At iterate   30    f=  7.65365D+00    |proj g|=  5.35429D-03
#
# At iterate   31    f=  7.65364D+00    |proj g|=  5.76899D-03
#
# At iterate   32    f=  7.65363D+00    |proj g|=  4.38121D-03
#
# At iterate   33    f=  7.65361D+00    |proj g|=  1.46931D-02
#
# At iterate   34    f=  7.65359D+00    |proj g|=  5.38085D-03
#
# At iterate   35    f=  7.65358D+00    |proj g|=  5.78844D-03
#
# At iterate   36    f=  7.65357D+00    |proj g|=  6.57456D-03
#
# At iterate   37    f=  7.65355D+00    |proj g|=  1.10762D-02
#
# At iterate   38    f=  7.65353D+00    |proj g|=  4.53468D-03
#
# At iterate   39    f=  7.65351D+00    |proj g|=  3.71108D-03
#
# At iterate   40    f=  7.65349D+00    |proj g|=  5.89795D-03
#
# At iterate   41    f=  7.65349D+00    |proj g|=  1.50964D-02
#
# At iterate   42    f=  7.65347D+00    |proj g|=  4.12248D-03
#
# At iterate   43    f=  7.65346D+00    |proj g|=  3.51061D-03
#
# At iterate   44    f=  7.65346D+00    |proj g|=  5.53841D-03
#
# At iterate   45    f=  7.65345D+00    |proj g|=  5.86473D-03
#
# At iterate   46    f=  7.65344D+00    |proj g|=  5.21290D-03
#
# At iterate   47    f=  7.65343D+00    |proj g|=  4.07647D-03
#
# At iterate   48    f=  7.65341D+00    |proj g|=  6.58273D-03
#
# At iterate   49    f=  7.65340D+00    |proj g|=  1.04156D-02
#
# At iterate   50    f=  7.65339D+00    |proj g|=  5.10179D-03
#
# At iterate   51    f=  7.65338D+00    |proj g|=  3.67999D-03
#
# At iterate   52    f=  7.65337D+00    |proj g|=  4.29710D-03
#
# At iterate   53    f=  7.65336D+00    |proj g|=  7.84786D-03
#
# At iterate   54    f=  7.65336D+00    |proj g|=  3.01688D-03
#
# At iterate   55    f=  7.65335D+00    |proj g|=  1.15588D-03
#
# At iterate   56    f=  7.65335D+00    |proj g|=  1.16431D-03
#
# At iterate   57    f=  7.65335D+00    |proj g|=  1.53086D-03
#
# At iterate   58    f=  7.65335D+00    |proj g|=  2.03570D-03
#
# At iterate   59    f=  7.65335D+00    |proj g|=  8.60201D-04
#
# At iterate   60    f=  7.65335D+00    |proj g|=  8.39862D-04
#
# At iterate   61    f=  7.65335D+00    |proj g|=  1.24949D-03
#
# At iterate   62    f=  7.65335D+00    |proj g|=  2.66223D-03
#
# At iterate   63    f=  7.65335D+00    |proj g|=  8.49720D-04
#
# At iterate   64    f=  7.65335D+00    |proj g|=  8.51230D-04
#
# At iterate   65    f=  7.65335D+00    |proj g|=  1.10445D-03
#
# At iterate   66    f=  7.65335D+00    |proj g|=  2.47145D-03
#
# At iterate   67    f=  7.65335D+00    |proj g|=  8.89955D-04
#
# At iterate   68    f=  7.65335D+00    |proj g|=  6.00320D-04
#
# At iterate   69    f=  7.65334D+00    |proj g|=  7.90745D-04
#
# At iterate   70    f=  7.65334D+00    |proj g|=  1.59091D-03
#
# At iterate   71    f=  7.65334D+00    |proj g|=  5.98543D-04
#
# At iterate   72    f=  7.65334D+00    |proj g|=  4.95692D-04
#
# At iterate   73    f=  7.65334D+00    |proj g|=  6.07070D-04
#
# At iterate   74    f=  7.65334D+00    |proj g|=  1.64961D-03
#
# At iterate   75    f=  7.65334D+00    |proj g|=  5.41611D-04
#
# At iterate   76    f=  7.65334D+00    |proj g|=  4.99689D-04
#
# At iterate   77    f=  7.65334D+00    |proj g|=  6.62403D-04
#
# At iterate   78    f=  7.65334D+00    |proj g|=  6.02540D-04
#
# At iterate   79    f=  7.65334D+00    |proj g|=  5.48894D-04
#
# At iterate   80    f=  7.65334D+00    |proj g|=  2.56239D-04
#
# At iterate   81    f=  7.65334D+00    |proj g|=  4.73310D-04
#
# At iterate   82    f=  7.65334D+00    |proj g|=  4.49685D-04
#
# At iterate   83    f=  7.65334D+00    |proj g|=  7.70761D-04
#
# At iterate   84    f=  7.65334D+00    |proj g|=  1.95577D-04
#
# At iterate   85    f=  7.65334D+00    |proj g|=  2.15561D-04
#
# At iterate   86    f=  7.65334D+00    |proj g|=  3.39995D-04
#
# At iterate   87    f=  7.65334D+00    |proj g|=  3.97637D-04
#
# At iterate   88    f=  7.65334D+00    |proj g|=  5.21361D-04
#
# At iterate   89    f=  7.65334D+00    |proj g|=  2.43361D-04
#
# At iterate   90    f=  7.65334D+00    |proj g|=  1.93445D-04
#
# At iterate   91    f=  7.65334D+00    |proj g|=  2.69029D-04
#
# At iterate   92    f=  7.65334D+00    |proj g|=  3.04734D-04
#
# At iterate   93    f=  7.65334D+00    |proj g|=  1.96110D-04
#
# At iterate   94    f=  7.65334D+00    |proj g|=  1.88738D-04
#
# At iterate   95    f=  7.65334D+00    |proj g|=  2.00107D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    95     95    103    101     0     2   2.001D-04   7.653D+00
#   F =   7.6533421065497045
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#                                  ETS Results
# ==============================================================================
# Dep. Variable:                  Price   No. Observations:                 1118
# Model:                      ETS(MAdM)   Log Likelihood               -8556.436
# Date:                Tue, 11 Jun 2024   AIC                          17306.873
# Time:                        18:33:29   BIC                          17793.745
# Sample:                             0   HQIC                         17490.914
#                                - 1118   Scale                            0.001
# Covariance Type:               approx
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# smoothing_level         0.9999      0.028     35.431      0.000       0.945       1.055
# smoothing_trend         0.0015      0.006      0.233      0.816      -0.011       0.014
# smoothing_seasonal   5.925e-05        nan        nan        nan         nan         nan
# damping_trend           0.9800      0.040     24.544      0.000       0.902       1.058
# initial_level        1.973e+04    821.133     24.028      0.000    1.81e+04    2.13e+04
# initial_trend          63.5395    124.511      0.510      0.610    -180.498     307.577
# initial_seasonal.0      1.0181      0.052     19.523      0.000       0.916       1.120
# initial_seasonal.1      1.0162      0.053     19.246      0.000       0.913       1.120
# initial_seasonal.2      1.0145      0.053     19.103      0.000       0.910       1.119
# initial_seasonal.3      1.0098      0.054     18.761      0.000       0.904       1.115
# initial_seasonal.4      1.0095      0.054     18.669      0.000       0.903       1.115
# initial_seasonal.5      0.9985      0.054     18.498      0.000       0.893       1.104
# initial_seasonal.6      0.9925      0.055     18.065      0.000       0.885       1.100
# initial_seasonal.7      0.9887      0.054     18.160      0.000       0.882       1.095
# initial_seasonal.8      0.9838      0.055     17.842      0.000       0.876       1.092
# initial_seasonal.9      0.9756      0.056     17.369      0.000       0.865       1.086
# initial_seasonal.10     0.9926      0.058     16.994      0.000       0.878       1.107
# initial_seasonal.11     0.9901      0.059     16.884      0.000       0.875       1.105
# initial_seasonal.12     0.9840      0.058     16.997      0.000       0.871       1.097
# initial_seasonal.13     0.9916      0.058     17.159      0.000       0.878       1.105
# initial_seasonal.14     1.0006      0.057     17.465      0.000       0.888       1.113
# initial_seasonal.15     0.9857      0.057     17.145      0.000       0.873       1.098
# initial_seasonal.16     1.0046      0.060     16.706      0.000       0.887       1.123
# initial_seasonal.17     1.0034      0.061     16.564      0.000       0.885       1.122
# initial_seasonal.18     1.0163      0.062     16.349      0.000       0.894       1.138
# initial_seasonal.19     1.0005      0.062     16.095      0.000       0.879       1.122
# initial_seasonal.20     1.0020      0.062     16.037      0.000       0.880       1.124
# initial_seasonal.21     1.0088      0.063     16.025      0.000       0.885       1.132
# initial_seasonal.22     1.0003      0.062     16.021      0.000       0.878       1.123
# initial_seasonal.23     1.0053      0.063     15.981      0.000       0.882       1.129
# initial_seasonal.24     1.0097      0.063     16.046      0.000       0.886       1.133
# initial_seasonal.25     1.0104      0.063     16.121      0.000       0.888       1.133
# initial_seasonal.26     1.0138      0.064     15.855      0.000       0.888       1.139
# initial_seasonal.27     1.0329      0.066     15.645      0.000       0.904       1.162
# initial_seasonal.28     1.0293      0.066     15.577      0.000       0.900       1.159
# initial_seasonal.29     1.0265      0.066     15.662      0.000       0.898       1.155
# initial_seasonal.30     1.0125      0.064     15.772      0.000       0.887       1.138
# initial_seasonal.31     1.0027      0.064     15.677      0.000       0.877       1.128
# initial_seasonal.32     1.0104      0.065     15.592      0.000       0.883       1.137
# initial_seasonal.33     1.0095      0.064     15.666      0.000       0.883       1.136
# initial_seasonal.34     0.9932      0.064     15.585      0.000       0.868       1.118
# initial_seasonal.35     0.9932      0.064     15.421      0.000       0.867       1.119
# initial_seasonal.36     0.9970      0.064     15.591      0.000       0.872       1.122
# initial_seasonal.37     0.9929      0.064     15.629      0.000       0.868       1.117
# initial_seasonal.38     0.9830      0.063     15.514      0.000       0.859       1.107
# initial_seasonal.39     0.9848      0.064     15.358      0.000       0.859       1.110
# initial_seasonal.40     0.9942      0.065     15.188      0.000       0.866       1.123
# initial_seasonal.41     0.9991      0.066     15.197      0.000       0.870       1.128
# initial_seasonal.42     0.9927      0.066     15.083      0.000       0.864       1.122
# initial_seasonal.43     0.9866      0.065     15.276      0.000       0.860       1.113
# initial_seasonal.44     0.9843      0.063     15.522      0.000       0.860       1.109
# initial_seasonal.45     0.9778      0.063     15.478      0.000       0.854       1.102
# initial_seasonal.46     0.9783      0.063     15.409      0.000       0.854       1.103
# initial_seasonal.47     0.9749      0.063     15.519      0.000       0.852       1.098
# initial_seasonal.48     0.9724      0.062     15.586      0.000       0.850       1.095
# initial_seasonal.49     0.9691      0.063     15.466      0.000       0.846       1.092
# initial_seasonal.50     0.9520      0.062     15.465      0.000       0.831       1.073
# initial_seasonal.51     0.9551      0.062     15.470      0.000       0.834       1.076
# initial_seasonal.52     0.9324      0.060     15.532      0.000       0.815       1.050
# initial_seasonal.53     0.9271      0.059     15.582      0.000       0.810       1.044
# initial_seasonal.54     0.9201      0.058     15.838      0.000       0.806       1.034
# initial_seasonal.55     0.9180      0.057     16.080      0.000       0.806       1.030
# initial_seasonal.56     0.9128      0.058     15.834      0.000       0.800       1.026
# initial_seasonal.57     0.9094      0.057     15.987      0.000       0.798       1.021
# initial_seasonal.58     0.9198      0.058     15.901      0.000       0.806       1.033
# initial_seasonal.59     0.9186      0.058     15.772      0.000       0.804       1.033
# initial_seasonal.60     0.9286      0.058     15.925      0.000       0.814       1.043
# initial_seasonal.61     0.9330      0.059     15.782      0.000       0.817       1.049
# initial_seasonal.62     0.9292      0.058     15.903      0.000       0.815       1.044
# initial_seasonal.63     0.9220      0.057     16.077      0.000       0.810       1.034
# initial_seasonal.64     0.9244      0.058     16.048      0.000       0.812       1.037
# initial_seasonal.65     0.9199      0.057     16.204      0.000       0.809       1.031
# initial_seasonal.66     0.9242      0.056     16.529      0.000       0.815       1.034
# initial_seasonal.67     0.9244      0.055     16.819      0.000       0.817       1.032
# initial_seasonal.68     0.9309      0.056     16.572      0.000       0.821       1.041
# initial_seasonal.69     0.9294      0.056     16.465      0.000       0.819       1.040
# initial_seasonal.70     0.9519      0.057     16.640      0.000       0.840       1.064
# initial_seasonal.71     0.9650      0.058     16.523      0.000       0.851       1.079
# initial_seasonal.72     0.9587      0.058     16.612      0.000       0.846       1.072
# initial_seasonal.73     0.9675      0.057     16.847      0.000       0.855       1.080
# initial_seasonal.74     0.9717      0.057     16.986      0.000       0.860       1.084
# initial_seasonal.75     0.9644      0.057     16.988      0.000       0.853       1.076
# initial_seasonal.76     0.9840      0.057     17.132      0.000       0.871       1.097
# initial_seasonal.77     0.9703      0.055     17.619      0.000       0.862       1.078
# initial_seasonal.78     0.9590      0.054     17.906      0.000       0.854       1.064
# initial_seasonal.79     0.9711      0.054     18.034      0.000       0.866       1.077
# initial_seasonal.80     0.9629      0.054     17.767      0.000       0.857       1.069
# initial_seasonal.81     0.9649      0.054     17.818      0.000       0.859       1.071
# initial_seasonal.82     0.9588      0.052     18.281      0.000       0.856       1.062
# initial_seasonal.83     0.9619      0.054     17.973      0.000       0.857       1.067
# initial_seasonal.84     0.9667      0.054     17.991      0.000       0.861       1.072
# initial_seasonal.85     0.9667      0.052     18.604      0.000       0.865       1.069
# initial_seasonal.86     0.9771      0.051     19.288      0.000       0.878       1.076
# initial_seasonal.87     0.9982      0.050     19.813      0.000       0.899       1.097
# initial_seasonal.88     1.0040      0.052     19.435      0.000       0.903       1.105
# initial_seasonal.89     1.0000      0.042     23.696      0.000       0.917       1.083
# ===================================================================================
# Ljung-Box (Q):                      172.10   Jarque-Bera (JB):              5336.68
# Prob(Q):                              0.65   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.13   Skew:                            -1.01
# Prob(H) (two-sided):                  0.23   Kurtosis:                        13.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using numerical (complex-step) differentiation.

# %%
y_pred = res.forecast(480)

# %%
# 6. Quá trình tạo index predict 90 ngày tiếp theo
last_index =  df1.index[-1]
last_data = pd.RangeIndex(start=last_index, stop=last_index+90, step=1)
last_data1 = pd.RangeIndex(start=last_index, stop=last_index+30, step=1)
last_data2 = pd.RangeIndex(start=last_index+31, stop=last_index+60, step=1)
last_data3 = pd.RangeIndex(start=last_index+61, stop=last_index+90, step=1)

x_next_90_days = np.array(range(last_index+1, last_index+91)).reshape(-1, 1)

y_next_90_days = res.forecast(len(x_next_90_days))
y_next_90_days
# Out:
# 1118    20598.538378
# 1119    20521.071365
# 1120    20877.552604
# 1121    20938.991318
# 1122    20981.521010
#             ...
# 1203    19234.489705
# 1204    19342.421049
# 1205    19384.501784
# 1206    19530.169659
# 1207    19640.473430
# Name: simulation, Length: 90, dtype: float64

# %%
test_mae = mean_absolute_error(test_data, y_pred)
test_mape = mean_absolute_percentage_error(test_data, y_pred)
test_rmse = sqrt(mean_squared_error(test_data, y_pred))

print('MAE:', test_mae)
print('RMSE:', test_rmse)
print('MAPE:', test_mape)
# Out:
# MAE: 4640.983690003291
# RMSE: 5605.060683396158
# MAPE: 0.3441301718437472

# %%
plt.plot(train_data.index, train_data['Price'])
plt.plot(test_data.index, test_data['Price'])
plt.plot(test_data.index, y_pred)
plt.plot(last_data1,y_next_90_days[0:30])
plt.plot(last_data2,y_next_90_days[31:60])
plt.plot(last_data3,y_next_90_days[61:90])
plt.legend(['Train', 'Test', 'Predictions','Next30Day', 'Next60Day', 'Next90Day'])
plt.show()
